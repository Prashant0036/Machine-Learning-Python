# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
atmbl=pd.read_csv("Automobile_data.csv")

# %%
atmbl.shape
# Out:
# (61, 10)

# %%
atmbl.head(n=50)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
atmbl.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
sns.histplot(atmbl["horsepower"])
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
atmbl.value_counts(atmbl["horsepower"])
# Out:
# horsepower
# 68     7
# 62     6
# 70     4
# 101    4
# 69     3
# 182    3
# 110    2
# 100    2
# 114    2
# 111    2
# 52     2
# 176    2
# 88     2
# 123    2
# 184    2
# 207    2
# 156    1
# 262    1
# 154    1
# 152    1
# 48     1
# 121    1
# 115    1
# 102    1
# 85     1
# 78     1
# 76     1
# 72     1
# 55     1
# 288    1
# dtype: int64

# %%
sns.histplot(atmbl["average-mileage"])
# Out:
# <Axes: xlabel='average-mileage', ylabel='Count'>

# %%
barchart=sns.countplot(x="average-mileage",data=atmbl)
barchart.set_xticklabels(barchart.get_xticklabels(),rotation=40)
# Out:
# [Text(0, 0, '13'),
#  Text(1, 0, '14'),
#  Text(2, 0, '15'),
#  Text(3, 0, '16'),
#  Text(4, 0, '17'),
#  Text(5, 0, '18'),
#  Text(6, 0, '19'),
#  Text(7, 0, '21'),
#  Text(8, 0, '22'),
#  Text(9, 0, '23'),
#  Text(10, 0, '24'),
#  Text(11, 0, '25'),
#  Text(12, 0, '26'),
#  Text(13, 0, '27'),
#  Text(14, 0, '30'),
#  Text(15, 0, '31'),
#  Text(16, 0, '35'),
#  Text(17, 0, '37'),
#  Text(18, 0, '38'),
#  Text(19, 0, '45'),
#  Text(20, 0, '47')]

# %%
sns.histplot(atmbl["average-mileage"])
# Out:
# <Axes: xlabel='average-mileage', ylabel='Count'>

# %%
sns.regplot(x="price",y="average-mileage",data="atmbl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.regplot(x="price",y="average-mileage",data="atmbl")
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:747, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     736 def regplot(
#     737     data=None, *, x=None, y=None,
#     738     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     744     scatter_kws=None, line_kws=None, ax=None
#     745 ):
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
# ...

# %%
atmbl.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
atmbl=atmbl.dropna()
atmbl
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
sns.regplot(x="horsepower",y="average-mileage",data="atmbl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sns.regplot(x="horsepower",y="average-mileage",data="atmbl")
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:747, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     736 def regplot(
#     737     data=None, *, x=None, y=None,
#     738     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     744     scatter_kws=None, line_kws=None, ax=None
#     745 ):
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
# ...

# %%
atmbl.dtypes
# Out:
# index                 int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.regplot(x="1",y="2",data="temp")
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:747, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     736 def regplot(
#     737     data=None, *, x=None, y=None,
#     738     x_estimator=None, x_bins=None, x_ci="ci",
#    (...)
#     744     scatter_kws=None, line_kws=None, ax=None
#     745 ):
# --> 747     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     748                                  scatter, fit_reg, ci, n_boot, units, seed,
#     749                                  order, logistic, lowess, robust, logx,
# ...
